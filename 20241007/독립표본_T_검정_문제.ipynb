# %% [markdown]
# ## 문제
# - 주어진 데이터(data/toothgrowth.csv)에는 기니피그 60마리의 치아 길이, 투여한 비타민 C 종류, 투여량이 저장되어 있다.  오렌지주스를 투여받은 기니피그의 치아 길이 평균이 아스코르브산을 투여받은 기니피그의 치아 길이 평균과 일치하는지 t-검정(Two Sample t-test)를 통해 답하고자 한다. 가설은 아래와 같다.
# - 가설검정
#     + 귀무가설 : 만들어보세요
#     투여한 약제별 치아의 평균 길이는 같다
#
#     + 대립가설 : 만들어보세요
#     투여한 약제별 치아의 평균 길이는 같지 않다
# - 데이터의 변수
#     + len : 치아의 길이
#     + supp : 투여한 약제(VC: 아스코르브산, OJ: 오렌지주스)
#     + does : 투여량
# - 단, 데이터의 각 변수들은 정규분포를 만족하며, 두 그룹은 등분산을 띤다.
# - 문제 1: 표본평균 $\overline{X_{OJ}}$, $\overline{X_{VC}}$를 구하시오.
# - 문제 2: 위의 가설을 검정하기 위한 검정통계량을 구하시오. (반올림하여 소숫점 둘째 자리까지 계산)
# - 문제 3: 위의 통계량에 대한 p-값을 구하고 (반올림하여 소숫점 넷째 자리까지 계산), 유의수준 0.05하에서 가설검정의 결과를 채택/기각 중 하나로 선택하시오.

# %% [markdown]
# ## 데이터 불러오기

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
url = "/content/drive/MyDrive/Colab Notebooks/2024_2025/imbank/1007/toothgrowth.csv"
df = pd.read_csv(url)
df.head()
# Out:
#     len supp  dose
# 0   4.2   VC   0.5
# 1  11.5   VC   0.5
# 2   7.3   VC   0.5
# 3   5.8   VC   0.5
# 4   6.4   VC   0.5

# %%
#

# %% [markdown]
# ## 가설검정
# - 독립표본 T-검정은 정규성 검정 뿐만 아니라, 두 그룹이 등분산성을 띠는지 확인하는 작업 필요
# - Levene 검정을 사용한 등분산성 검정이 선행되어야 함
#
#
# 가설 설정
# 귀무 가설
# : 두 그룹의 분산은 같다.
#
# 대립 가설
# : 두 그룹의 분산은 같지 않다

# %%
from scipy import stats
stats.levene(df.loc[df['supp']=='VC', 'len'], df.loc[df['supp']=='OJ', 'len'])
df
# Out:
#      len supp  dose
# 0    4.2   VC   0.5
# 1   11.5   VC   0.5
# 2    7.3   VC   0.5
# 3    5.8   VC   0.5
# 4    6.4   VC   0.5
# 5   10.0   VC   0.5
# 6   11.2   VC   0.5
# 7   11.2   VC   0.5
# 8    5.2   VC   0.5
# 9    7.0   VC   0.5
# 10  16.5   VC   1.0
# 11  16.5   VC   1.0
# 12  15.2   VC   1.0
# 13  17.3   VC   1.0
# 14  22.5   VC   1.0
# 15  17.3   VC   1.0
# 16  13.6   VC   1.0
# 17  14.5   VC   1.0
# 18  18.8   VC   1.0
# 19  15.5   VC   1.0
# 20  23.6   VC   2.0
# 21  18.5   VC   2.0
# 22  33.9   VC   2.0
# 23  25.5   VC   2.0
# 24  26.4   VC   2.0
# 25  32.5   VC   2.0
# 26  26.7   VC   2.0
# 27  21.5   VC   2.0
# 28  23.3   VC   2.0
# 29  29.5   VC   2.0
# 30  15.2   OJ   0.5
# 31  21.5   OJ   0.5
# 32  17.6   OJ   0.5
# 33   9.7   OJ   0.5
# 34  14.5   OJ   0.5
# 35  10.0   OJ   0.5
# 36   8.2   OJ   0.5
# 37   9.4   OJ   0.5
# 38  16.5   OJ   0.5
# 39   9.7   OJ   0.5
# 40  19.7   OJ   1.0
# 41  23.3   OJ   1.0
# 42  23.6   OJ   1.0
# 43  26.4   OJ   1.0
# 44  20.0   OJ   1.0
# 45  25.2   OJ   1.0
# 46  25.8   OJ   1.0
# 47  21.2   OJ   1.0
# 48  14.5   OJ   1.0
# 49  27.3   OJ   1.0
# 50  25.5   OJ   2.0
# 51  26.4   OJ   2.0
# 52  22.4   OJ   2.0
# 53  24.5   OJ   2.0
# 54  24.8   OJ   2.0
# 55  30.9   OJ   2.0
# 56  26.4   OJ   2.0
# 57  27.3   OJ   2.0
# 58  29.4   OJ   2.0
# 59  23.0   OJ   2.0

# %% [markdown]
# - p_value가 0.275 이므로 귀무가설을 채택한다.
#
# ---

# %% [markdown]
# ## 문제 1
# - 표본평균 $\overline{X_{OJ}}$, $\overline{X_{VC}}$를 구하시오.

# %%
#
oj_mean=df.loc[df['supp']=='VC', 'len'].mean()
oj_mean
round(oj_mean,2)
# Out:
# 16.96

# %%
#
# Out:
# 20.66

# %% [markdown]
# ## 문제 2
# - 위의 가설을 검정하기 위한 검정통계량을 구하시오. (반올림하여 소숫점 둘째 자리까지 계산)

# %%
#
# Out:
# -1.9153 0.06

# %%
from scipy import stats

#t,p=stats.ttest_ind(x,y,equl_var=True)

# %% [markdown]
# ## 문제 3.
# - 위의 통계량에 대한 p-값을 구하고 (반올림하여 소숫점 넷째 자리까지 계산), 유의수준 0.05하에서 가설검정의 결과를 채택/기각 중 하나로 선택하시오.

# %%
#
# Out:
# 0.0604

# %%
'''
if p > 0.05:
    print("귀무가설 채택")
else :
    print("귀무가설 기각 => 대립 가설 채택")
    '''
# Out:
# '\nif p > 0.05:\n    print("귀무가설 채택")\nelse :\n    print("귀무가설 기각 => 대립 가설 채택")\n    '

# %%
#
# Out:
# 채택

# %% [markdown]
# 임상 실험 실패 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 주가 폭락ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
#
# 그냥 오렌지 주스 사먹이는 것과 큰 차이 없네요
